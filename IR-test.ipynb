# %%
x<-sample(100,100)

# %%
summary(x)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    1.00   25.75   50.50   50.50   75.25  100.00

# %%
error<-rnorm(100)

# %%
y<-log(x)+error

# %%
plot(x,y)
# Out:
# plot without title

# %%
mod<-lm(y~x)

# %%
summary(mod)$coefficients
# Out:
#               Estimate  Std. Error   t value     Pr(>|t|)
# (Intercept) 2.49501542 0.185523730 13.448497 5.532366e-24
# x           0.02447203 0.003189454  7.672796 1.257360e-11
